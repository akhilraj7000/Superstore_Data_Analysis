# %% [markdown]
# # __Superstore Data Analysis__

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/superstore_final_dataset.csv')
df.head(2)
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
#
#   Customer_Name   Segment        Country       City     State  Postal_Code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
#
#   Region       Product_ID   Category Sub_Category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product_Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9800 non-null   int64
#  1   Order_ID       9800 non-null   object
#  2   Order_Date     9800 non-null   object
#  3   Ship_Date      9800 non-null   object
#  4   Ship_Mode      9800 non-null   object
#  5   Customer_ID    9800 non-null   object
#  6   Customer_Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal_Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product_ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub_Category   9800 non-null   object
#  16  Product_Name   9800 non-null   object
# ...

# %%
new_dict = {}
for col in df.columns:
  new_dict.update({col: df[col].nunique()})

unique_dict =  pd.DataFrame(new_dict, index=['Unique'])
unique_dict
# Out:
#         Row_ID  Order_ID  Order_Date  Ship_Date  Ship_Mode  Customer_ID  \
# Unique    9800      4922        1230       1326          4          793
#
#         Customer_Name  Segment  Country  City  State  Postal_Code  Region  \
# Unique            793        3        1   529     49          626       4
#
#         Product_ID  Category  Sub_Category  Product_Name  Sales
# Unique        1861         3            17          1849   5757

# %% [markdown]
# ## Removing unwanted column(s)

# %%
df.drop(['Row_ID', 'Country'], axis = 1, inplace = True)
df.head(2)
# Out:
#          Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 1  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
#
#   Customer_Name   Segment       City     State  Postal_Code Region  \
# 0   Claire Gute  Consumer  Henderson  Kentucky      42420.0  South
# 1   Claire Gute  Consumer  Henderson  Kentucky      42420.0  South
#
#         Product_ID   Category Sub_Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product_Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %% [markdown]
# ## Removing duplicate rows ( there could be duplicate rows excluding Row_ID column ).

# %%
df[df.duplicated()]
# Out:
#             Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 3406  US-2015-150119  23/04/2015  27/04/2015  Standard Class    LB-16795
#
#        Customer_Name      Segment      City State  Postal_Code Region  \
# 3406  Laurel Beltran  Home Office  Columbus  Ohio      43229.0   East
#
#            Product_ID   Category Sub_Category  \
# 3406  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product_Name    Sales
# 3406  Global Leather Highback Executive Chair with P...  281.372

# %%
df.drop_duplicates(inplace = True, ignore_index = True)
df.head(2)
# Out:
#          Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 1  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
#
#   Customer_Name   Segment       City     State  Postal_Code Region  \
# 0   Claire Gute  Consumer  Henderson  Kentucky      42420.0  South
# 1   Claire Gute  Consumer  Henderson  Kentucky      42420.0  South
#
#         Product_ID   Category Sub_Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product_Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %%
df.shape
# Out:
# (9799, 16)

# %% [markdown]
# ## Removing rows for which few values are missing.

# %%
df.isna().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Ship_Date         0
# Ship_Mode         0
# Customer_ID       0
# Customer_Name     0
# Segment           0
# City              0
# State             0
# Postal_Code      11
# Region            0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Sales             0
# dtype: int64

# %%
df.dropna(inplace = True)
df.head(2)
# Out:
#          Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 1  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
#
#   Customer_Name   Segment       City     State  Postal_Code Region  \
# 0   Claire Gute  Consumer  Henderson  Kentucky      42420.0  South
# 1   Claire Gute  Consumer  Henderson  Kentucky      42420.0  South
#
#         Product_ID   Category Sub_Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product_Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %%
df.shape
# Out:
# (9788, 16)

# %% [markdown]
# ## Remove irrelevant values from each column if any. Validation of all values for a column( order date and ship date value must be in correct date format ). For each entry in dataset ship date >= order date

# %% [markdown]
# ### Transforming to correct datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9788 entries, 0 to 9798
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       9788 non-null   object
#  1   Order_Date     9788 non-null   object
#  2   Ship_Date      9788 non-null   object
#  3   Ship_Mode      9788 non-null   object
#  4   Customer_ID    9788 non-null   object
#  5   Customer_Name  9788 non-null   object
#  6   Segment        9788 non-null   object
#  7   City           9788 non-null   object
#  8   State          9788 non-null   object
#  9   Postal_Code    9788 non-null   float64
#  10  Region         9788 non-null   object
#  11  Product_ID     9788 non-null   object
#  12  Category       9788 non-null   object
#  13  Sub_Category   9788 non-null   object
#  14  Product_Name   9788 non-null   object
#  15  Sales          9788 non-null   float64
# dtypes: float64(2), object(14)
# memory usage: 1.3+ MB

# %%
df = df.astype({'Order_Date': 'datetime64[ns]', 'Ship_Date': 'datetime64[ns]', 'Postal_Code': 'int'})
df['Postal_Code'] = df['Postal_Code'].map(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9788 entries, 0 to 9798
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       9788 non-null   object
#  1   Order_Date     9788 non-null   datetime64[ns]
#  2   Ship_Date      9788 non-null   datetime64[ns]
#  3   Ship_Mode      9788 non-null   object
#  4   Customer_ID    9788 non-null   object
#  5   Customer_Name  9788 non-null   object
#  6   Segment        9788 non-null   object
#  7   City           9788 non-null   object
#  8   State          9788 non-null   object
#  9   Postal_Code    9788 non-null   object
#  10  Region         9788 non-null   object
#  11  Product_ID     9788 non-null   object
#  12  Category       9788 non-null   object
#  13  Sub_Category   9788 non-null   object
#  14  Product_Name   9788 non-null   object
#  15  Sales          9788 non-null   float64
# dtypes: datetime64[ns](2), float64(1), object(13)
# ...

# %% [markdown]
# ### Checking weather Ship_Date < Order_Date

# %%
# Ship_Date < Order_Date -> 1684 rows
df.loc[df['Ship_Date'] < df['Order_Date']].head(2)
# Out:
#          Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 2  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment             City       State Postal_Code Region  \
# 2  Darrin Van Huff  Corporate      Los Angeles  California       90036   West
# 3    Sean O Donnel   Consumer  Fort Lauderdale     Florida       33311  South
#
#         Product_ID         Category Sub_Category  \
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
#
#                                         Product_Name     Sales
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775

# %%
df['Ship_Mode'].value_counts()
# Out:
# Standard Class    5848
# Second Class      1901
# First Class       1501
# Same Day           538
# Name: Ship_Mode, dtype: int64

# %%
# Error when the 'Ship_Mode' is 'Second Class' -> 305 rows
df.loc[(df['Ship_Mode'] == 'Second Class') & (df['Ship_Date'] < df['Order_Date'])].head(2)
# Out:
#           Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 2   CA-2017-138688 2017-12-06 2017-06-16  Second Class    DV-13045
# 18  CA-2015-143336 2015-08-27 2015-01-09  Second Class    ZD-21925
#
#          Customer_Name    Segment           City       State Postal_Code  \
# 2      Darrin Van Huff  Corporate    Los Angeles  California       90036
# 18  Zuschuss Donatelli   Consumer  San Francisco  California       94109
#
#    Region       Product_ID         Category Sub_Category  \
# 2    West  OFF-LA-10000240  Office Supplies       Labels
# 18   West  OFF-AR-10003056  Office Supplies          Art
#
#                                          Product_Name  Sales
# 2   Self-Adhesive Address Labels for Typewriters b...  14.62
# 18                                         Newell 341   8.56

# %%
# Error when the 'Ship_Mode' is 'First Class' -> 157 rows
df.loc[(df['Ship_Mode'] == 'First Class') & (df['Ship_Date'] < df['Order_Date'])].head(2)
# Out:
#           Order_ID Order_Date  Ship_Date    Ship_Mode Customer_ID  \
# 44  CA-2017-118255 2017-11-03 2017-03-13  First Class    ON-18715
# 45  CA-2017-118255 2017-11-03 2017-03-13  First Class    ON-18715
#
#     Customer_Name    Segment   City      State Postal_Code   Region  \
# 44  Odella Nelson  Corporate  Eagan  Minnesota       55122  Central
# 45  Odella Nelson  Corporate  Eagan  Minnesota       55122  Central
#
#          Product_ID         Category Sub_Category  \
# 44  TEC-AC-10000171       Technology  Accessories
# 45  OFF-BI-10003291  Office Supplies      Binders
#
#                                          Product_Name  Sales
# 44  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...  45.98
# 45  Wilson Jones Leather-Like Binders with DublLoc...  17.46

# %%
# Error when the 'Ship_Mode' is 'Same Day' -> 2 rows
df.loc[(df['Ship_Mode'] == 'Same Day') & (df['Ship_Date'] < df['Order_Date'])]
# Out:
#             Order_ID Order_Date  Ship_Date Ship_Mode Customer_ID  \
# 8768  CA-2017-151148 2017-12-09 2017-09-13  Same Day    PO-19180
# 8769  CA-2017-151148 2017-12-09 2017-09-13  Same Day    PO-19180
#
#           Customer_Name      Segment        City     State Postal_Code Region  \
# 8768  Philisse Overcash  Home Office  Louisville  Colorado       80027   West
# 8769  Philisse Overcash  Home Office  Louisville  Colorado       80027   West
#
#            Product_ID    Category Sub_Category  \
# 8768  TEC-PH-10001870  Technology       Phones
# 8769  FUR-CH-10002304   Furniture       Chairs
#
#                                            Product_Name    Sales
# 8768  Lunatik TT5L-002 Taktik Strike Impact Protecti...  146.952
# 8769             Global Stack Chair without Arms, Black   83.136

# %%
# Error when the 'Ship_Mode' is 'Standard Class' -> 1220 rows
df.loc[(df['Ship_Mode'] == 'Standard Class') & (df['Ship_Date'] < df['Order_Date'])].head(2)
# Out:
#          Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 3  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#    Customer_Name   Segment             City    State Postal_Code Region  \
# 3  Sean O Donnel  Consumer  Fort Lauderdale  Florida       33311  South
# 4  Sean O Donnel  Consumer  Fort Lauderdale  Florida       33311  South
#
#         Product_ID         Category Sub_Category  \
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                     Product_Name     Sales
# 3  Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                  Eldon Fold N Roll Cart System   22.3680

# %% [markdown]
# ### Removing rows where 'Ship_Date' < 'Order_Date'

# %%
df = df.loc[df['Ship_Date'] >= df['Order_Date']]
df.shape
# Out:
# (8104, 16)

# %%
df.reset_index(drop = True, inplace = True)
df.head(2)
# Out:
#          Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 0  CA-2017-152156 2017-08-11 2017-11-11  Second Class    CG-12520
# 1  CA-2017-152156 2017-08-11 2017-11-11  Second Class    CG-12520
#
#   Customer_Name   Segment       City     State Postal_Code Region  \
# 0   Claire Gute  Consumer  Henderson  Kentucky       42420  South
# 1   Claire Gute  Consumer  Henderson  Kentucky       42420  South
#
#         Product_ID   Category Sub_Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product_Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %% [markdown]
# ## Export the cleaned dataset as a .csv file: prefer UTF-8 encoding.

# %%
df.to_csv('Superstore_v2.csv', encoding='utf-8')
